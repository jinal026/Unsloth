# %% [markdown]
# <a href="https://colab.research.google.com/github/jinal026/Unsloth/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-31T12:30:53.544018Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.07}
# {"timestamp": "2026-03-31T12:30:55.830220Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.93}
# {"timestamp": "2026-03-31T12:30:56.127928Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.4}
# {"timestamp": "2026-03-31T12:30:56.423592Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.93}
# {"timestamp": "2026-03-31T12:30:57.840028Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-03-31T12:31:09.622715Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 134.97}
# {"timestamp": "2026-03-31T12:31:09.941405Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.92}
# {"timestamp": "2026-03-31T12:31:10.223956Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-03-31T12:31:10.242140Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.91}
# {"timestamp": "2026-03-31T12:31:10.563772Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.28}
# {"timestamp": "2026-03-31T12:31:13.342356Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/studio", "status_code": 200, "process_time_ms": 1.27}
# {"timestamp": "2026-03-31T12:31:14.641622Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.5}
# {"timestamp": "2026-03-31T12:31:14.941698Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.21}
# {"timestamp": "2026-03-31T12:31:16.505815Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-03-31T12:31:16.828475Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.69}
# {"timestamp": "2026-03-31T12:32:39.570312Z", "level": "info", "event": "Getting model config for: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T12:32:39.576246Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# config.json: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-31T12:32:40.723161Z", "level": "info", "event": "Model config result for unsloth/llama-3-8b-bnb-4bit: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=8192"}
# {"timestamp": "2026-03-31T12:32:40.813398Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/llama-3-8b-bnb-4bit", "status_code": 200, "process_time_ms": 1244.89}
# {"timestamp": "2026-03-31T12:34:06.181632Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/datasets/local", "status_code": 200, "process_time_ms": 2.59}
# =={"timestamp": "2026-03-31T12:41:20.498009Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T12:41:20.676729Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# README.md: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-31T12:41:22.931540Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T12:41:23.202485Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2707.55}
# =={"timestamp": "2026-03-31T12:53:37.951954Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T12:53:38.174547Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T12:53:39.106738Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T12:53:39.305332Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1355.6}
# {"timestamp": "2026-03-31T12:55:49.308566Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T12:55:49.404382Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T12:55:50.138209Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T12:55:50.335642Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1029.1}
# {"timestamp": "2026-03-31T12:55:50.694727Z", "level": "info", "event": "Starting training job with model: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T12:55:50.700790Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# {"timestamp": "2026-03-31T12:55:50.701429Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-31T12:55:51.580923Z", "level": "info", "event": "Training subprocess started (pid=15310)"}
# {"timestamp": "2026-03-31T12:55:51.605905Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 914.27}
# ={"timestamp": "2026-03-31T12:55:53.407709Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 4.97}
# ={"timestamp": "2026-03-31T13:03:42.143133Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.16}
# {"timestamp": "2026-03-31T13:03:42.337961Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.23}
# {"timestamp": "2026-03-31T13:03:43.021771Z", "level": "info", "event": "Found 1 training runs in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-31T13:03:43.025196Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/checkpoints", "status_code": 200, "process_time_ms": 6.27}
# {"timestamp": "2026-03-31T13:03:43.030446Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.51}
# {"timestamp": "2026-03-31T13:04:34.089782Z", "level": "info", "event": "Spawning fresh export subprocess for '/root/.unsloth/studio/outputs/unsloth_llama-3-8b-bnb-4bit_1774961893'"}
# {"timestamp": "2026-03-31T13:04:34.097327Z", "level": "info", "event": "Export subprocess started (pid=17748)"}
# {"timestamp": "2026-03-31T13:04:34.794804Z", "level": "info", "event": "Export subprocess status: Importing Unsloth..."}
# {"timestamp": "2026-03-31T13:05:07.091702Z", "level": "info", "event": "Export subprocess status: Loading checkpoint: /root/.unsloth/studio/outputs/unsloth_llama-3-8b-bnb-4bit_1774961893"}
# {"timestamp": "2026-03-31T13:05:39.722006Z", "level": "info", "event": "Checkpoint '/root/.unsloth/studio/outputs/unsloth_llama-3-8b-bnb-4bit_1774961893' loaded in subprocess"}
# {"timestamp": "2026-03-31T13:05:39.724002Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/export/load-checkpoint", "status_code": 200, "process_time_ms": 65637.64}
# =

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
