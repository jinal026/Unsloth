# %% [markdown]
# <a href="https://colab.research.google.com/github/jinal026/Unsloth/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh
# Out:
# fatal: destination path 'unsloth' already exists and is not an empty directory.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#   frontend       up to date
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [====================] 11/11  finalizing
#   deps           installed
#   transformers   5.x pre-installed
#                  resolved llama.cpp tag: b8508
#                  installing prebuilt llama.cpp...
#                  existing install detected -- validating update
#   llama.cpp      prebuilt installed and validated
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-03-31 13:14:05 [info     ] 🦥 Starting Unsloth Studio...
# 2026-03-31 13:14:05 [info     ]    Loading backend...
# 2026-03-31 13:14:05 [info     ]    Starting server...
# INFO:     Started server process [19682]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA — Tesla T4
# {"timestamp": "2026-03-31T13:14:13.692299Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-03-31T13:14:13.788576Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-03-31T13:14:15.501659Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="http://localhost:8888" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace;">
#             http://localhost:8888
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-03-31T13:14:49.014233Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.99}
# {"timestamp": "2026-03-31T13:14:50.702006Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.74}
# {"timestamp": "2026-03-31T13:14:51.062196Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.85}
# {"timestamp": "2026-03-31T13:14:51.368260Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.4}
# {"timestamp": "2026-03-31T13:14:54.073819Z", "level": "info", "event": "Getting model config for: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T13:14:54.082437Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# {"timestamp": "2026-03-31T13:14:55.069892Z", "level": "info", "event": "Model config result for unsloth/llama-3-8b-bnb-4bit: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=8192"}
# {"timestamp": "2026-03-31T13:14:55.160547Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-03-31T13:14:55.167955Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/llama-3-8b-bnb-4bit", "status_code": 200, "process_time_ms": 1097.72}
# {"timestamp": "2026-03-31T13:14:55.169321Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1098.83}
# {"timestamp": "2026-03-31T13:14:55.174322Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:14:55.421315Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:14:55.517231Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 1.69}
# {"timestamp": "2026-03-31T13:14:56.944778Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:14:57.156724Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 3085.89}
# {"timestamp": "2026-03-31T13:17:03.836192Z", "level": "info", "event": "Checking format for dataset: santhoshmlops/Skai_Gemma_Instruct_ChatTemplate"}
# {"timestamp": "2026-03-31T13:17:03.966863Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/359 [00:00<?, ?B/s]
# {"timestamp": "2026-03-31T13:17:06.432853Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:17:06.440539Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2606.52}
# {"timestamp": "2026-03-31T13:17:06.779162Z", "level": "info", "event": "Checking format for dataset: santhoshmlops/Skai_Gemma_Instruct_ChatTemplate"}
# {"timestamp": "2026-03-31T13:17:06.878384Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:17:07.640342Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:17:07.643344Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 866.12}
# {"timestamp": "2026-03-31T13:17:53.198895Z", "level": "info", "event": "Checking format for dataset: amarmahdi1112/human_chat_dataset_processed"}
# {"timestamp": "2026-03-31T13:17:53.615173Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/313 [00:00<?, ?B/s]
# {"timestamp": "2026-03-31T13:17:54.952654Z", "level": "info", "event": "Checking format for dataset: amarmahdi1112/human_chat_dataset_processed"}
# {"timestamp": "2026-03-31T13:17:55.061567Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:17:55.341200Z", "level": "info", "event": "Format check result: requires_mapping=False, format=alpaca, is_image=False"}
# {"timestamp": "2026-03-31T13:17:55.344205Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2147.85}
# {"timestamp": "2026-03-31T13:17:56.036191Z", "level": "info", "event": "Format check result: requires_mapping=False, format=alpaca, is_image=False"}
# {"timestamp": "2026-03-31T13:17:56.040083Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1088.97}
# {"timestamp": "2026-03-31T13:18:45.479948Z", "level": "info", "event": "Checking format for dataset: mrcuddle/HumanLike-Casual-2K"}
# {"timestamp": "2026-03-31T13:18:45.600674Z", "level": "info", "event": "Tier 1: loading single file dpo_dataset_4_09_2024_more_casual_convs_much_2k.json"}
# {"timestamp": "2026-03-31T13:18:47.726339Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:18:47.729330Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2253.28}
# {"timestamp": "2026-03-31T13:18:48.043596Z", "level": "info", "event": "Checking format for dataset: mrcuddle/HumanLike-Casual-2K"}
# {"timestamp": "2026-03-31T13:18:48.132831Z", "level": "info", "event": "Tier 1: loading single file dpo_dataset_4_09_2024_more_casual_convs_much_2k.json"}
# {"timestamp": "2026-03-31T13:18:51.088106Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:18:51.091261Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 3049.7}
# ={"timestamp": "2026-03-31T13:21:09.983784Z", "level": "info", "event": "Checking format for dataset: csebuetnlp/dailydialogue_bn"}
# {"timestamp": "2026-03-31T13:21:10.141972Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# README.md: 0.00B [00:00, ?B/s]
# dailydialogue_bn.py: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-31T13:21:10.793226Z", "level": "error", "event": "Error checking dataset format: Dataset scripts are no longer supported, but found dailydialogue_bn.py", "exc_info": true}
# {"timestamp": "2026-03-31T13:21:10.796646Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 814.88}
# {"timestamp": "2026-03-31T13:21:12.359373Z", "level": "info", "event": "Checking format for dataset: csebuetnlp/dailydialogue_bn"}
# {"timestamp": "2026-03-31T13:21:12.451820Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-03-31T13:21:12.559969Z", "level": "error", "event": "Error checking dataset format: Dataset scripts are no longer supported, but found dailydialogue_bn.py", "exc_info": true}
# {"timestamp": "2026-03-31T13:21:12.561862Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 204.58}
# {"timestamp": "2026-03-31T13:21:30.698282Z", "level": "info", "event": "Checking format for dataset: roskoN/dailydialog"}
# {"timestamp": "2026-03-31T13:21:30.885002Z", "level": "info", "event": "Tier 1: loading single file test.zip"}
# README.md:   0%|          | 0.00/581 [00:00<?, ?B/s]
# dailydialog.py: 0.00B [00:00, ?B/s]
# {"timestamp": "2026-03-31T13:21:31.495522Z", "level": "warning", "event": "Tier 1 (single-file) failed: Dataset scripts are no longer supported, but found dailydialog.py"}
# {"timestamp": "2026-03-31T13:21:31.497123Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-03-31T13:21:31.606284Z", "level": "error", "event": "Error checking dataset format: Dataset scripts are no longer supported, but found dailydialog.py", "exc_info": true}
# {"timestamp": "2026-03-31T13:21:31.607428Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 911.02}
# {"timestamp": "2026-03-31T13:21:34.797999Z", "level": "info", "event": "Checking format for dataset: roskoN/dailydialog"}
# {"timestamp": "2026-03-31T13:21:34.889269Z", "level": "info", "event": "Tier 1: loading single file test.zip"}
# {"timestamp": "2026-03-31T13:21:34.989454Z", "level": "warning", "event": "Tier 1 (single-file) failed: Dataset scripts are no longer supported, but found dailydialog.py"}
# {"timestamp": "2026-03-31T13:21:34.990035Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# {"timestamp": "2026-03-31T13:21:35.087905Z", "level": "error", "event": "Error checking dataset format: Dataset scripts are no longer supported, but found dailydialog.py", "exc_info": true}
# {"timestamp": "2026-03-31T13:21:35.088798Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 292.67}
# {"timestamp": "2026-03-31T13:21:51.954897Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:21:52.061556Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:21:54.256257Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:21:54.308312Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:21:54.448259Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:21:54.470203Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2517.67}
# {"timestamp": "2026-03-31T13:21:56.045025Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:21:56.225470Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1922.68}
# {"timestamp": "2026-03-31T13:22:41.779208Z", "level": "info", "event": "Checking format for dataset: equiron-ai/like_a_human"}
# {"timestamp": "2026-03-31T13:22:41.922194Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/340 [00:00<?, ?B/s]
# {"timestamp": "2026-03-31T13:22:43.857195Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:22:43.859813Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2082.54}
# {"timestamp": "2026-03-31T13:22:45.062813Z", "level": "info", "event": "Checking format for dataset: equiron-ai/like_a_human"}
# {"timestamp": "2026-03-31T13:22:45.155168Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:22:45.731139Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:22:45.734246Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 673.21}
# {"timestamp": "2026-03-31T13:23:24.249943Z", "level": "info", "event": "Checking format for dataset: chillcharlie/humanlike_test_actions"}
# {"timestamp": "2026-03-31T13:23:24.393237Z", "level": "info", "event": "Tier 1: loading single file train/AlarmClock-3.15.02-debug.apk_1743571915.258724.json"}
# README.md:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# {"timestamp": "2026-03-31T13:23:25.834745Z", "level": "info", "event": "Checking format for dataset: chillcharlie/humanlike_test_actions"}
# {"timestamp": "2026-03-31T13:23:25.959630Z", "level": "info", "event": "Tier 1: loading single file train/AlarmClock-3.15.02-debug.apk_1743571915.258724.json"}
# {"timestamp": "2026-03-31T13:23:25.983543Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:23:25.991431Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1744.1}
# {"timestamp": "2026-03-31T13:23:27.036197Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:23:27.046855Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1214.02}
# {"timestamp": "2026-03-31T13:23:56.197885Z", "level": "info", "event": "Checking format for dataset: TouchNight/HumanlikeRP"}
# {"timestamp": "2026-03-31T13:23:56.344458Z", "level": "info", "event": "Tier 1: loading single file 0.1humanlike.parquet"}
# {"timestamp": "2026-03-31T13:23:58.184300Z", "level": "info", "event": "Checking format for dataset: TouchNight/HumanlikeRP"}
# {"timestamp": "2026-03-31T13:23:58.275655Z", "level": "info", "event": "Tier 1: loading single file 0.1humanlike.parquet"}
# {"timestamp": "2026-03-31T13:24:05.742572Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:24:05.983314Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:24:06.136512Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 9939.81}
# {"timestamp": "2026-03-31T13:24:06.276769Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 8094.43}
# {"timestamp": "2026-03-31T13:24:31.503561Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat-Enriched"}
# {"timestamp": "2026-03-31T13:24:31.645799Z", "level": "info", "event": "Tier 1: loading single file corrected_test_freq.jsonl"}
# README.md: 0.00B [00:00, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# {"timestamp": "2026-03-31T13:24:33.088064Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat-Enriched"}
# {"timestamp": "2026-03-31T13:24:33.207213Z", "level": "info", "event": "Tier 1: loading single file corrected_test_freq.jsonl"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:24:34.014582Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:24:34.015054Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:24:34.301971Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:24:34.302497Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:24:35.674680Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:24:35.677325Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 4175.84}
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:24:35.687620Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:24:35.689824Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 2603.93}
# ={"timestamp": "2026-03-31T13:24:52.203462Z", "level": "info", "event": "Checking format for dataset: TouchNight/HumanlikeRP"}
# {"timestamp": "2026-03-31T13:24:52.373454Z", "level": "info", "event": "Tier 1: loading single file 0.1humanlike.parquet"}
# {"timestamp": "2026-03-31T13:24:54.866762Z", "level": "info", "event": "Checking format for dataset: TouchNight/HumanlikeRP"}
# {"timestamp": "2026-03-31T13:24:54.959003Z", "level": "info", "event": "Tier 1: loading single file 0.1humanlike.parquet"}
# {"timestamp": "2026-03-31T13:24:56.360799Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:24:56.639992Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 4438.82}
# {"timestamp": "2026-03-31T13:24:58.767795Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:24:58.978161Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 4115.8}
# {"timestamp": "2026-03-31T13:25:30.052822Z", "level": "info", "event": "Checking format for dataset: equiron-ai/like_a_human"}
# {"timestamp": "2026-03-31T13:25:30.145742Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:25:30.857921Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:25:30.861358Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 810.29}
# {"timestamp": "2026-03-31T13:25:32.646452Z", "level": "info", "event": "Checking format for dataset: equiron-ai/like_a_human"}
# {"timestamp": "2026-03-31T13:25:32.743520Z", "level": "info", "event": "Tier 1: loading single file data/train-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:25:33.298874Z", "level": "info", "event": "Format check result: requires_mapping=False, format=custom_heuristic, is_image=False"}
# {"timestamp": "2026-03-31T13:25:33.302288Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 659.34}
# {"timestamp": "2026-03-31T13:26:17.929763Z", "level": "info", "event": "Checking format for dataset: mrcuddle/HumanLike-Casual-2K"}
# {"timestamp": "2026-03-31T13:26:18.017260Z", "level": "info", "event": "Tier 1: loading single file dpo_dataset_4_09_2024_more_casual_convs_much_2k.json"}
# {"timestamp": "2026-03-31T13:26:19.321887Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:26:19.325758Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1397.84}
# {"timestamp": "2026-03-31T13:26:21.118401Z", "level": "info", "event": "Checking format for dataset: mrcuddle/HumanLike-Casual-2K"}
# {"timestamp": "2026-03-31T13:26:21.208640Z", "level": "info", "event": "Tier 1: loading single file dpo_dataset_4_09_2024_more_casual_convs_much_2k.json"}
# {"timestamp": "2026-03-31T13:26:22.053653Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:26:22.058326Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 941.59}
# {"timestamp": "2026-03-31T13:26:56.197890Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat"}
# {"timestamp": "2026-03-31T13:26:56.329825Z", "level": "info", "event": "Tier 1: loading single file pre-build/corrected_test_freq.jsonl"}
# README.md: 0.00B [00:00, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/pre-build/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/pre-build/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:26:57.947785Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:26:57.948367Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# {"timestamp": "2026-03-31T13:26:58.697944Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat"}
# {"timestamp": "2026-03-31T13:26:58.796237Z", "level": "info", "event": "Tier 1: loading single file pre-build/corrected_test_freq.jsonl"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/pre-build/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/pre-build/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:26:59.877285Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:26:59.878708Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:27:00.058963Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:27:00.064335Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 3867.65}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat@fee4a71dd8ce5b471dd46e1b7aab2acbd1b9e1be/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:27:01.223848Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:27:01.225142Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 2529.12}
# {"timestamp": "2026-03-31T13:27:19.615634Z", "level": "info", "event": "Checking format for dataset: JefiRyan/Topical-Chat"}
# {"timestamp": "2026-03-31T13:27:19.886580Z", "level": "info", "event": "Tier 1: loading single file data.csv"}
# {"timestamp": "2026-03-31T13:27:21.577887Z", "level": "info", "event": "Checking format for dataset: JefiRyan/Topical-Chat"}
# {"timestamp": "2026-03-31T13:27:21.670879Z", "level": "info", "event": "Tier 1: loading single file data.csv"}
# {"timestamp": "2026-03-31T13:27:23.049160Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:27:23.054341Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 3440.41}
# {"timestamp": "2026-03-31T13:27:23.873906Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:27:23.876692Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2300.39}
# {"timestamp": "2026-03-31T13:27:38.386602Z", "level": "info", "event": "Checking format for dataset: Fishball02/topical-chat"}
# {"timestamp": "2026-03-31T13:27:38.557999Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/573 [00:00<?, ?B/s]
# {"timestamp": "2026-03-31T13:27:40.325509Z", "level": "info", "event": "Checking format for dataset: Fishball02/topical-chat"}
# {"timestamp": "2026-03-31T13:27:40.419424Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# {"timestamp": "2026-03-31T13:27:40.484837Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:27:40.488361Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2106.9}
# {"timestamp": "2026-03-31T13:27:41.712834Z", "level": "info", "event": "Format check result: requires_mapping=True, format=unknown, is_image=False"}
# {"timestamp": "2026-03-31T13:27:41.715019Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1391.57}
# {"timestamp": "2026-03-31T13:27:57.761119Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat-Enriched"}
# {"timestamp": "2026-03-31T13:27:57.895583Z", "level": "info", "event": "Tier 1: loading single file corrected_test_freq.jsonl"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:27:58.895820Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:27:58.896396Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# {"timestamp": "2026-03-31T13:27:59.582019Z", "level": "info", "event": "Checking format for dataset: Conversational-Reasoning/Topical-Chat-Enriched"}
# {"timestamp": "2026-03-31T13:27:59.670421Z", "level": "info", "event": "Tier 1: loading single file corrected_test_freq.jsonl"}
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:27:59.911310Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:27:59.912708Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 2153.28}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/corrected_test_freq.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:28:00.470369Z", "level": "warning", "event": "Tier 1 (single-file) failed: JSON parse error: Column() changed from object to array in row 0"}
# {"timestamp": "2026-03-31T13:28:00.473545Z", "level": "info", "event": "Tier 2: falling back to full streaming load_dataset"}
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# ERROR:datasets.packaged_modules.json.json:Failed to load JSON from file 'hf://datasets/Conversational-Reasoning/Topical-Chat-Enriched@b393eaf7db077d3f14a8e1e642fe01d24c695b06/pre-build/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column() changed from object to array in row 0
# {"timestamp": "2026-03-31T13:28:01.591509Z", "level": "error", "event": "Error checking dataset format: JSON parse error: Column() changed from object to array in row 0", "exc_info": true}
# {"timestamp": "2026-03-31T13:28:01.592386Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 500, "process_time_ms": 2011.87}
# {"timestamp": "2026-03-31T13:28:18.986613Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:28:19.081328Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:28:19.802198Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:28:20.018250Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1033.61}
# {"timestamp": "2026-03-31T13:28:20.819274Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:28:20.913243Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:28:21.556944Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:28:21.770474Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 953.37}
# {"timestamp": "2026-03-31T13:29:11.350154Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:29:11.445946Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:29:12.163759Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:29:12.383032Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1034.98}
# {"timestamp": "2026-03-31T13:29:12.758079Z", "level": "info", "event": "Starting training job with model: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T13:29:12.764657Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# {"timestamp": "2026-03-31T13:29:12.767613Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-31T13:29:12.769538Z", "level": "info", "event": "ExportOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-03-31T13:29:13.055188Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Nemotron-3-Nano-30B-A3B-GGUF', 'unsloth/Qwen3.5-397B-A17B-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/Qwen3-VL-4B-Instruct-GGUF', 'unsloth/gemma-3-27b-it-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Llama-3.2-1B-Instruct-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-1.5B-GGUF', 'unsloth/NVIDIA-Nemotron-3-Super-120B-A12B-GGUF', 'unsloth/Qwen3-4B-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/Qwen3-4B-Instruct-2507-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/gemma-3-4b-it-GGUF', 'unsloth/MiniMax-M2.5-GGUF', 'unsloth/DeepSeek-R1-0528-Qwen3-8B-GGUF', 'unsloth/Qwen3-VL-8B-Instruct-GGUF', 'unsloth/Qwen3-VL-30B-A3B-Instruct-GGUF']"}
# {"timestamp": "2026-03-31T13:29:13.056288Z", "level": "info", "event": "Top hub models: ['unsloth/GLM-4.7-Flash-FP8-Dynamic', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-0.6B', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/gpt-oss-20b', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-1.7B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/GLM-4.7-Flash', 'unsloth/gpt-oss-120b-BF16', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/Qwen2-7B', 'unsloth/gpt-oss-20b-BF16', 'unsloth/Llama-3.2-1B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3.5-0.8B', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Llama-3.2-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-Base', 'unsloth/Qwen3-4B', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-8B', 'unsloth/Qwen3-4B-bnb-4bit', 'unsloth/llama-3-8b-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/DeepSeek-V3-0324-BF16', 'unsloth/Qwen3-VL-4B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen2.5-0.5B-unsloth-bnb-4bit']"}
# {"timestamp": "2026-03-31T13:29:13.632951Z", "level": "info", "event": "Training subprocess started (pid=24890)"}
# {"timestamp": "2026-03-31T13:29:13.654663Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 900.95}
# {"timestamp": "2026-03-31T13:29:15.376067Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 6.39}
# ={"timestamp": "2026-03-31T13:31:12.376706Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 6.59}
# ={"timestamp": "2026-03-31T13:36:37.551175Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.84}
# ={"timestamp": "2026-03-31T13:44:20.714117Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T13:44:20.831481Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T13:44:21.607332Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T13:44:21.839094Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 1126.81}
# {"timestamp": "2026-03-31T13:44:22.478009Z", "level": "info", "event": "Starting training job with model: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T13:44:22.484469Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# {"timestamp": "2026-03-31T13:44:23.323201Z", "level": "info", "event": "Training subprocess started (pid=29021)"}
# {"timestamp": "2026-03-31T13:44:23.339589Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/train/start", "status_code": 200, "process_time_ms": 863.15}
# {"timestamp": "2026-03-31T13:44:24.797896Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 1.76}
# =========={"timestamp": "2026-03-31T14:31:12.459913Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.42}
# ============{"timestamp": "2026-03-31T15:31:12.400844Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.97}
# ============{"timestamp": "2026-03-31T16:31:12.511621Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.57}
# ==={"timestamp": "2026-03-31T16:46:44.948800Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 4.65}
# {"timestamp": "2026-03-31T16:46:46.754728Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.65}
# {"timestamp": "2026-03-31T16:46:47.086190Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 5.7}
# {"timestamp": "2026-03-31T16:46:47.408434Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.81}
# {"timestamp": "2026-03-31T16:46:49.281637Z", "level": "info", "event": "Getting model config for: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T16:46:49.293956Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/llama/unsloth_llama-3-8b-bnb-4bit.yaml"}
# {"timestamp": "2026-03-31T16:46:49.852558Z", "level": "info", "event": "Model config result for unsloth/llama-3-8b-bnb-4bit: is_vision=False, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=8192"}
# {"timestamp": "2026-03-31T16:46:49.949492Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/llama-3-8b-bnb-4bit", "status_code": 200, "process_time_ms": 673.12}
# {"timestamp": "2026-03-31T16:46:49.958626Z", "level": "info", "event": "Checking format for dataset: agentlans/Conversational-Reasoning-Topical-Chat"}
# {"timestamp": "2026-03-31T16:46:50.079600Z", "level": "info", "event": "Tier 1: loading single file test.jsonl.zst"}
# {"timestamp": "2026-03-31T16:46:50.321140Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 3.22}
# {"timestamp": "2026-03-31T16:46:51.963175Z", "level": "info", "event": "Format check result: requires_mapping=False, format=sharegpt, is_image=False"}
# Standardizing chat format (num_proc=1):   0%|          | 0/10 [00:00<?, ? examples/s]
# {"timestamp": "2026-03-31T16:46:52.259596Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 2983.01}
# =={"timestamp": "2026-03-31T16:56:10.395892Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 8.85}
# {"timestamp": "2026-03-31T16:56:15.708622Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/runs", "status_code": 200, "process_time_ms": 5.6}
# ===={"timestamp": "2026-03-31T17:17:32.211686Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/chat", "status_code": 200, "process_time_ms": 7.06}
# {"timestamp": "2026-03-31T17:17:34.575282Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.69}
# {"timestamp": "2026-03-31T17:17:34.883561Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.7}
# {"timestamp": "2026-03-31T17:17:37.163898Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 401, "process_time_ms": 3.54}
# {"timestamp": "2026-03-31T17:17:37.177516Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 401, "process_time_ms": 3.36}
# {"timestamp": "2026-03-31T17:17:37.187118Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 401, "process_time_ms": 5.6}
# {"timestamp": "2026-03-31T17:17:37.192909Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 401, "process_time_ms": 4.98}
# {"timestamp": "2026-03-31T17:17:37.487068Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.5}
# {"timestamp": "2026-03-31T17:17:37.560104Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.25}
# {"timestamp": "2026-03-31T17:17:37.585414Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 4.85}
# {"timestamp": "2026-03-31T17:17:37.592702Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.63}
# {"timestamp": "2026-03-31T17:17:37.817855Z", "level": "info", "event": "Found 2 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-31T17:17:37.819923Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T17:17:37.824212Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T17:17:37.830758Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-31T17:17:37.831760Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 37.02}
# {"timestamp": "2026-03-31T17:17:37.856332Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 7.38}
# {"timestamp": "2026-03-31T17:17:37.886180Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 6.88}
# {"timestamp": "2026-03-31T17:17:37.891444Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 3.05}
# {"timestamp": "2026-03-31T17:17:40.699820Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 41.4}
# {"timestamp": "2026-03-31T17:17:40.753415Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 52.59}
# {"timestamp": "2026-03-31T17:17:40.756528Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 55.58}
# {"timestamp": "2026-03-31T17:17:41.057422Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 3.12}
# {"timestamp": "2026-03-31T17:17:53.330729Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.43}
# {"timestamp": "2026-03-31T17:17:55.742496Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 11.15}
# {"timestamp": "2026-03-31T17:17:55.753692Z", "level": "info", "event": "Found 2 trained LoRA adapters in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-03-31T17:17:55.756871Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T17:17:55.759336Z", "level": "info", "event": "Detected base model from adapter_config.json: unsloth/llama-3-8b-bnb-4bit"}
# {"timestamp": "2026-03-31T17:17:55.762860Z", "level": "info", "event": "Found 1 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-03-31T17:17:55.770557Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 24.18}
# {"timestamp": "2026-03-31T17:17:55.774565Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 28.09}
# {"timestamp": "2026-03-31T17:17:55.777522Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 30.98}
# {"timestamp": "2026-03-31T17:17:55.779450Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 32.83}
# {"timestamp": "2026-03-31T17:17:56.905814Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.16}
# {"timestamp": "2026-03-31T17:17:56.927963Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 2.0}
# {"timestamp": "2026-03-31T17:17:57.227213Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 3.52}
# {"timestamp": "2026-03-31T17:18:17.502833Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/train/progress", "status_code": 200, "process_time_ms": 1.97}
# ==={"timestamp": "2026-03-31T17:31:41.049898Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.55}
# {"timestamp": "2026-03-31T17:31:41.066648Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 3.45}
# {"timestamp": "2026-03-31T17:31:41.073252Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.95}
# ==

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
